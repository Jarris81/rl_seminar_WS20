# %%
import gym

env = gym.make("Ant-v3")
env.
# Out:
# --------------------------------------------------------------------
# AttributeError                     Traceback (most recent call last)
# <ipython-input-23-2b90031102d7> in <module>
#       2
#       3 env = gym.make("Ant-v3")
# ----> 4 env.id
#
# ~/anaconda3/lib/python3.7/site-packages/gym/core.py in __getattr__(self, name)
#     216         if name.startswith('_'):
#     217             raise AttributeError("attempted to get missing private attribute '{}'".format(name))
# --> 218         return getattr(self.env, name)
#     219
#     220     @property
#
# AttributeError: 'AntEnv' object has no attribute 'id'

# %%
df.plot(kind="line")

# %%
type(int("dhddh50"))
# Out:
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# <ipython-input-26-4496692fe65c> in <module>
# ----> 1 type(int("dhddh50"))
#
# ValueError: invalid literal for int() with base 10: 'dhddh50'

# %%
#agent = DDPGAgent(env, gamma, tau, buffer_maxlen, critic_lr, actor_lr)
episode_rewards = mini_batch_train(env, agent, max_episodes, max_steps, batch_size)

episode_rewards = np.asarray(episode_rewards)

plt.plot(range(max_episodes), episode_rewards)
plt.show
# Out:
# Episode 0: -6.227128486655862
# Episode 1: 38.68995758477284
# Episode 2: 84.58583754221127
# Episode 3: 54.786340610441506
# Episode 4: 75.16854279862821
# Episode 5: 9.821676989169653
# Episode 6: 2.745117459354667
# Episode 7: 63.95846092260515
# Episode 8: -29.718149047625317
# Episode 9: 71.02337866491962
# Episode 10: 25.976701714550124
# Episode 11: 19.261139550863913
# Episode 12: -23.21924438665461
# Episode 13: -80.42593984360151
# Episode 14: 49.619410920951964
# Episode 15: 1.0706604500968924
# Episode 16: 3.023293617589564
# Episode 17: -38.7211087040165
# Episode 18: 145.22373697733212
# Episode 19: -28.121400836619465
# Episode 20: 19.254918111666267
# Episode 21: 13.592274809383664
# Episode 22: -23.57053790064701
# Episode 23: 89.18314399558047
# Episode 24: 38.6937438193362
# Episode 25: -27.83243198698527
# Episode 26: 79.6516292085387
# Episode 27: 261.7129385462546
# Episode 28: 32.3223328998642
# Episode 29: 28.8754955594385
# Episode 30: 9.233719206799384
# Episode 31: 18.05602912526524
# Episode 32: 57.07725865794078
# Episode 33: -0.321856000101174
# Episode 34: -54.36827050403071
# Episode 35: 10.79479466673198
# Episode 36: 44.4042120725214
# Episode 37: 23.719095614175192
# Episode 38: 50.5702797751313
# Episode 39: 23.72629899534333
# Episode 40: 38.9622042025246
# Episode 41: -10.18941207981039
# Episode 42: 37.62495484731183
# Episode 43: 5.184492866471501
# Episode 44: 18.68324297756835
# Episode 45: 41.93730560106736
# Episode 46: -18.190302732312002
# Episode 47: 32.91761335144455
# Episode 48: 42.90495679044109
# Episode 49: 4.027077051500239
# Episode 50: 15.373674589761254
# Episode 51: 12.590613214556816
# Episode 52: 16.51392453996342
# Episode 53: -10.816545090339988
# Episode 54: 37.12767109039808
# Episode 55: 0.05620182778360627
# Episode 56: -22.548134006406162
# Episode 57: 12.99641190944271
# Episode 58: 62.97872574110328
# Episode 59: 52.37330332813625
# Episode 60: 60.74293953802377
# Episode 61: 67.32583953384905
# Episode 62: 69.90162272517115
# Episode 63: -8.427781750860042
# Episode 64: 94.14626789765089
# Episode 65: 79.89139707352646
# Episode 66: 31.481240099931743
# Episode 67: 22.860192525686916
# Episode 68: 55.82667075138248
# Episode 69: 23.325415764250565
# Episode 70: 37.83694682425422
# Episode 71: 22.359046136461725
# Episode 72: 71.18143423438956
# Episode 73: 49.74370568735913
# Episode 74: 7.037829785307106
# Episode 75: 63.3398575807971
# Episode 76: 45.62728604983301
# Episode 77: 29.913895752288735
# Episode 78: 17.78853856280818
# Episode 79: 77.99335512792504
# Episode 80: 43.23545730355193
# Episode 81: 7.626862180075076
# Episode 82: 52.874768335703905
# Episode 83: 86.59118943769514
# Episode 84: 27.498207726502542
# Episode 85: 0.19854473155912278
# Episode 86: 28.051159382328926
# Episode 87: 79.67597497579547
# Episode 88: 61.206601607977866
# Episode 89: 0.8631447921013219
# Episode 90: 65.95259633822647
# Episode 91: 32.126693761776416
# Episode 92: 25.116084226812397
# Episode 93: 14.490596820586001
# Episode 94: 27.778646861834492
# Episode 95: 16.531235773614988
# Episode 96: 66.63737317810596
# Episode 97: 46.36803755598294
# Episode 98: 38.59147525038839
# Episode 99: 53.802694328016244
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from tensorforce import Agent, Environment
import matplotlib.pyplot as plt

# Pre-defined or custom environment
environment = Environment.create(
    environment='gym', level="MountainCarContinuous", max_episode_timesteps=300,
)


# Instantiate a Tensorforce agent
agent = Agent.create(
    agent='dpg', 
    environment=environment,
    memory=10000,
    batch_size=100,
)

rewards = []

# Train for 100 episodes
for _ in range(100):

    # Initialize episode
    states = environment.reset()
    terminal = False

    while not terminal:
        # Episode timestep
        actions = agent.act(states=states)
        states, terminal, reward = environment.execute(actions=actions)
        agent.observe(terminal=terminal, reward=reward)
        rewards.append(reward)

agent.close()
environment.close()

plt.plot(range(len(rewards)), rewards)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TensorforceError                          Traceback (most recent call last)
# <ipython-input-46-f5eef9a7d3da> in <module>
#      13     environment=environment,
#      14     memory=10000,
# ---> 15     batch_size=100,
#      16 )
#      17
#
# ~/anaconda3/lib/python3.7/site-packages/tensorforce/agents/agent.py in create(agent, environment, **kwargs)
#     112                 # Keyword specification
#     113                 agent = tensorforce.agents.agents[agent]
# --> 114                 return Agent.create(agent=agent, environment=environment, **kwargs)
#     115
#     116             else:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorforce/agents/agent.py in create(agent, environment, **kwargs)
#      83                     kwargs['max_episode_timesteps'] = environment.max_episode_timesteps()
#      84
# ---> 85             agent = agent(**kwargs)
#      86             assert isinstance(agent, Agent)
#      87             return Agent.create(agent=agent, environment=environment)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorforce/agents/dpg.py in __init__(self, states, actions, memory, max_episode_timesteps, network, batch_size, update_frequency, start_updating, learning_rate, horizon, discount, estimate_terminal, critic_network, critic_optimizer, preprocessing, exploration, variable_noise, l2_regularization, entropy_regularization, name, device, parallel_interactions, seed, execution, saver, summarizer, recorder, config)
#     271         if len(self.actions_spec) > 1 or action_spec['type'] != 'float' or \
#     272                 action_spec['shape'] != ():
# --> 273             raise TensorforceError.unexpected()
#
# TensorforceError: Unexpected error!

# %%
keys = [1,2,3]
values = [[4,5,6], [7,8,9], [10, 11, 12]]

my_dict = {key:value for (key,value) in zip(keys, values)}
my_dict
# Out:
# {1: [4, 5, 6], 2: [7, 8, 9], 3: [10, 11, 12]}
